# %%
# !git clone https://github.com/zhn66776/Tidal_try.git
# Out:
# Cloning into 'Tidal_try'...
# remote: Enumerating objects: 675, done.
# remote: Counting objects: 100% (320/320), done.
# remote: Compressing objects: 100% (186/186), done.
# remote: Total 675 (delta 172), reused 249 (delta 133), pack-reused 355 (from 1)
# Receiving objects: 100% (675/675), 81.98 MiB | 14.30 MiB/s, done.
# Resolving deltas: 100% (303/303), done.

# %%
cd Tidal_try
# Out:
# /content/Tidal_try

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math
from keras.models import Model
from keras.layers import Dense, GRU, Dropout, Bidirectional, Input
from keras.regularizers import l2
from keras.optimizers import Adam
from keras.callbacks import ReduceLROnPlateau
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import r2_score
import warnings
from sklearn.exceptions import UndefinedMetricWarning
import tensorflow as tf

np.random.seed(42)
tf.random.set_seed(42)
warnings.filterwarnings("ignore", category=UndefinedMetricWarning)

input_file = "dataProcessed/ABE5Y1_HA_processed.csv"
df = pd.read_csv(input_file, delimiter=',')
total_train_points = 10000
look_back_points = 100
total_test_points = 2000

total_required = total_train_points + look_back_points + total_test_points
if len(df) < total_required:
    raise ValueError(f"Dataset too small. Required: {total_required}, Current: {len(df)}")

max_start_index = len(df) - total_required
start_index = np.random.randint(0, max_start_index + 1)
print(f"Selected start index: {start_index}")

df_sampled = df.iloc[start_index:start_index + total_required].reset_index(drop=True)

anomaly = df_sampled['anomaly'].values.reshape(-1, 1)
utide = df_sampled['utide'].values.reshape(-1, 1)

utide_factor = 0.5
utide = utide * utide_factor

scaler_anomaly = MinMaxScaler(feature_range=(0, 1))
anomaly_scaled = scaler_anomaly.fit_transform(anomaly)

scaler_utide = MinMaxScaler(feature_range=(0, 1))
utide_scaled = scaler_utide.fit_transform(utide)

dataset_scaled_multi = np.hstack((anomaly_scaled, utide_scaled))
train_multi = dataset_scaled_multi[:total_train_points]
test_multi = dataset_scaled_multi[total_train_points : total_train_points + total_test_points + look_back_points]

def create_dataset_multi(dataset, look_back):
    dataX, dataY = [], []
    for i in range(len(dataset)-look_back):
        a = dataset[i:(i+look_back), :]
        dataX.append(a)
        dataY.append(dataset[i+look_back, 0])
    return np.array(dataX), np.array(dataY)

trainX_multi, trainY_multi = create_dataset_multi(train_multi, look_back_points)
testX_multi, testY_multi = create_dataset_multi(test_multi, look_back_points)

print("Multi-feature TrainX:", trainX_multi.shape, "TrainY:", trainY_multi.shape)
print("Multi-feature TestX:", testX_multi.shape, "TestY:", testY_multi.shape)

num_features_multi = 2

# bigru
def build_bigru_multi(input_shape):
    input_layer = Input(shape=input_shape)
    x = Bidirectional(GRU(700, return_sequences=True, kernel_regularizer=l2(0.0001)))(input_layer)
    x = Dropout(0.3)(x)
    x = Bidirectional(GRU(500, kernel_regularizer=l2(0.0001)))(x)
    x = Dropout(0.3)(x)
    output_layer = Dense(1)(x)
    model = Model(inputs=input_layer, outputs=output_layer)
    model.compile(loss='mse', optimizer=Adam(learning_rate=0.001))
    return model

model = build_bigru_multi((look_back_points, num_features_multi))

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, verbose=1, min_lr=1e-6)

epochs = 150
batch_size = 256

print("Training BiGRU_2feat...")
history = model.fit(trainX_multi, trainY_multi,
                    validation_split=0.1,
                    epochs=epochs,
                    batch_size=batch_size,
                    verbose=1,
                    callbacks=[reduce_lr])
print("BiGRU_2feat training completed.\n")

plt.figure(figsize=(12,8))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('BiGRU_2feat Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# rolling
def rolling_prediction_multi(model, test, scaler_anomaly, scaler_utide, look_back):
    total_tp = len(test) - look_back
    current_input = test[:look_back].copy()
    rolling_predictions = []
    actual_values = []
    utide_values = []
    r2_scores = []
    utide_r2_scores = []

    for i in range(total_tp):
        input_sequence = current_input.reshape(1, look_back, 2)
        prediction = model.predict(input_sequence, verbose=0)
        predicted_anomaly_scaled = prediction[0, 0]

        actual_anomaly_scaled = test[look_back + i, 0]
        actual_anomaly = scaler_anomaly.inverse_transform([[actual_anomaly_scaled]])[0, 0]
        actual_values.append(actual_anomaly)

        utide_scaled_val = test[look_back + i, 1]
        utide_val = scaler_utide.inverse_transform([[utide_scaled_val]])[0, 0]
        utide_values.append(utide_val)

        predicted_anomaly = scaler_anomaly.inverse_transform([[predicted_anomaly_scaled]])[0,0]
        rolling_predictions.append(predicted_anomaly)

        current_input = np.roll(current_input, -1, axis=0)
        if i < total_tp - 1:
            next_utide_scaled = test[look_back + i + 1, 1]
        else:
            next_utide_scaled = test[look_back + i, 1]

        current_input[-1, 0] = predicted_anomaly_scaled
        current_input[-1, 1] = next_utide_scaled

        if i >= 20:
            r2_scores.append(r2_score(actual_values, rolling_predictions))
            utide_r2_scores.append(r2_score(actual_values, utide_values))
        else:
            r2_scores.append(np.nan)
            utide_r2_scores.append(np.nan)

    return {
        'actual_values': np.array(actual_values),
        'predicted_values': np.array(rolling_predictions),
        'utide_values': np.array(utide_values),
        'r2_scores': np.array(r2_scores),
        'utide_r2_scores': np.array(utide_r2_scores)
    }

print("Performing rolling prediction with BiGRU_2feat...")
results = rolling_prediction_multi(model, test_multi, scaler_anomaly, scaler_utide, look_back_points)
print("BiGRU_2feat rolling prediction completed.\n")

actual_values_full = scaler_anomaly.inverse_transform(
    test_multi[look_back_points:look_back_points + total_test_points, 0].reshape(-1,1)).flatten()
utide_values_full = scaler_utide.inverse_transform(
    test_multi[look_back_points:look_back_points + total_test_points, 1].reshape(-1,1)).flatten()

r2_utide = r2_score(actual_values_full, utide_values_full)

# plot MSE、MAE
steps_to_plot = 100
x = np.arange(steps_to_plot)
width = 0.3

actual = results['actual_values'][:steps_to_plot]
predicted = results['predicted_values'][:steps_to_plot]
mse = (actual - predicted)**2
mae = np.abs(actual - predicted)

mse_utide = (actual_values_full[:steps_to_plot] - utide_values_full[:steps_to_plot])**2
mae_utide = np.abs(actual_values_full[:steps_to_plot] - utide_values_full[:steps_to_plot])

fig, axes = plt.subplots(1,2, figsize=(20,8))

# MSE
axes[0].bar(x, mse, width, label='BiGRU_2feat MSE', color='blue')
axes[0].bar(x + width, mse_utide, width, label='Utide MSE', color='grey')
axes[0].set_title('MSE Comparison (First 100 Steps)')
axes[0].set_xlabel('Time Step')
axes[0].set_ylabel('MSE')
axes[0].legend()
axes[0].set_xticks(x)

for i in range(steps_to_plot):
    errors = [mse[i], mse_utide[i]]
    min_idx = np.argmin(errors)
    min_x = x[i] if min_idx == 0 else x[i] + width
    axes[0].text(min_x, errors[min_idx] + 0.001, '*', ha='center', va='bottom', color='black')

# MAE
axes[1].bar(x, mae, width, label='BiGRU_2feat MAE', color='orange')
axes[1].bar(x + width, mae_utide, width, label='Utide MAE', color='grey')
axes[1].set_title('MAE Comparison (First 100 Steps)')
axes[1].set_xlabel('Time Step')
axes[1].set_ylabel('MAE')
axes[1].legend()
axes[1].set_xticks(x)

for i in range(steps_to_plot):
    errors = [mae[i], mae_utide[i]]
    min_idx = np.argmin(errors)
    min_x = x[i] if min_idx == 0 else x[i] + width
    axes[1].text(min_x, errors[min_idx] + 0.001, '*', ha='center', va='bottom', color='black')

plt.tight_layout()
plt.show()

# time tat r2 lower Utide
start_index_plot = 0
n_steps_plot = 300
indices = np.arange(start_index_plot, min(start_index_plot + n_steps_plot, total_test_points))

model_r2 = results['r2_scores'][indices]
falloff_indices = np.where(model_r2 < r2_utide)[0]
first_falloff = falloff_indices[0] if falloff_indices.size > 0 else "Never"
print(f"BiGRU_2feat R² falls below Utide at step: {first_falloff}")


plt.figure(figsize=(20,10))
plt.plot(actual_values_full[:steps_to_plot], label='Actual', color='black')
plt.plot(utide_values_full[:steps_to_plot], label='Utide', color='green', linestyle='--')
plt.plot(predicted, label='BiGRU_2feat Prediction', color='red')
plt.xlabel('Time Step')
plt.ylabel('Anomaly')
plt.title('Predictions vs Actual (First 100 Steps)')
plt.legend()
plt.show()
# Out:
# Selected start index: 121958
# Multi-feature TrainX: (9900, 100, 2) TrainY: (9900,)
# Multi-feature TestX: (2000, 100, 2) TestY: (2000,)
# Training BiGRU_2feat...
# Epoch 1/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 8s 82ms/step - loss: 0.4026 - val_loss: 0.1165 - learning_rate: 0.0010
# Epoch 2/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 0.1023 - val_loss: 0.0846 - learning_rate: 0.0010
# Epoch 3/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - loss: 0.0802 - val_loss: 0.0733 - learning_rate: 0.0010
# Epoch 4/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 0.0696 - val_loss: 0.0639 - learning_rate: 0.0010
# Epoch 5/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 0.0606 - val_loss: 0.0560 - learning_rate: 0.0010
# Epoch 6/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 0.0530 - val_loss: 0.0491 - learning_rate: 0.0010
# Epoch 7/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 0.0464 - val_loss: 0.0432 - learning_rate: 0.0010
# Epoch 8/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 0.0408 - val_loss: 0.0382 - learning_rate: 0.0010
# Epoch 9/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 0.0359 - val_loss: 0.0338 - learning_rate: 0.0010
# Epoch 10/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 0.0317 - val_loss: 0.0300 - learning_rate: 0.0010
# Epoch 11/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 0.0280 - val_loss: 0.0266 - learning_rate: 0.0010
# Epoch 12/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 0.0248 - val_loss: 0.0237 - learning_rate: 0.0010
# Epoch 13/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 0.0219 - val_loss: 0.0213 - learning_rate: 0.0010
# Epoch 14/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 0.0195 - val_loss: 0.0190 - learning_rate: 0.0010
# Epoch 15/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 0.0173 - val_loss: 0.0171 - learning_rate: 0.0010
# Epoch 16/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 0.0154 - val_loss: 0.0156 - learning_rate: 0.0010
# Epoch 17/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 0.0138 - val_loss: 0.0140 - learning_rate: 0.0010
# Epoch 18/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 0.0123 - val_loss: 0.0128 - learning_rate: 0.0010
# Epoch 19/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 0.0111 - val_loss: 0.0116 - learning_rate: 0.0010
# Epoch 20/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 0.0099 - val_loss: 0.0105 - learning_rate: 0.0010
# Epoch 21/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 0.0089 - val_loss: 0.0096 - learning_rate: 0.0010
# Epoch 22/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 0.0080 - val_loss: 0.0088 - learning_rate: 0.0010
# Epoch 23/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 0.0072 - val_loss: 0.0083 - learning_rate: 0.0010
# Epoch 24/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 0.0065 - val_loss: 0.0075 - learning_rate: 0.0010
# Epoch 25/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 0.0059 - val_loss: 0.0069 - learning_rate: 0.0010
# Epoch 26/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 0.0053 - val_loss: 0.0064 - learning_rate: 0.0010
# Epoch 27/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 0.0048 - val_loss: 0.0059 - learning_rate: 0.0010
# Epoch 28/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 0.0043 - val_loss: 0.0055 - learning_rate: 0.0010
# Epoch 29/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 0.0040 - val_loss: 0.0052 - learning_rate: 0.0010
# Epoch 30/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 0.0036 - val_loss: 0.0049 - learning_rate: 0.0010
# Epoch 31/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 0.0032 - val_loss: 0.0046 - learning_rate: 0.0010
# Epoch 32/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 0.0030 - val_loss: 0.0043 - learning_rate: 0.0010
# Epoch 33/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 0.0028 - val_loss: 0.0047 - learning_rate: 0.0010
# Epoch 34/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 0.0027 - val_loss: 0.0039 - learning_rate: 0.0010
# Epoch 35/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 0.0023 - val_loss: 0.0039 - learning_rate: 0.0010
# Epoch 36/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 0.0022 - val_loss: 0.0036 - learning_rate: 0.0010
# Epoch 37/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 0.0020 - val_loss: 0.0034 - learning_rate: 0.0010
# Epoch 38/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 0.0018 - val_loss: 0.0033 - learning_rate: 0.0010
# Epoch 39/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 0.0017 - val_loss: 0.0033 - learning_rate: 0.0010
# Epoch 40/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 0.0017 - val_loss: 0.0031 - learning_rate: 0.0010
# Epoch 41/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 0.0015 - val_loss: 0.0030 - learning_rate: 0.0010
# Epoch 42/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 0.0014 - val_loss: 0.0029 - learning_rate: 0.0010
# Epoch 43/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 0.0014 - val_loss: 0.0029 - learning_rate: 0.0010
# Epoch 44/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 0.0013 - val_loss: 0.0028 - learning_rate: 0.0010
# Epoch 45/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 0.0013 - val_loss: 0.0027 - learning_rate: 0.0010
# Epoch 46/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 0.0011 - val_loss: 0.0027 - learning_rate: 0.0010
# Epoch 47/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 0.0011 - val_loss: 0.0027 - learning_rate: 0.0010
# Epoch 48/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 0.0011 - val_loss: 0.0026 - learning_rate: 0.0010
# Epoch 49/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 0.0010 - val_loss: 0.0026 - learning_rate: 0.0010
# Epoch 50/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 9.6415e-04 - val_loss: 0.0025 - learning_rate: 0.0010
# Epoch 51/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 0.0010 - val_loss: 0.0026 - learning_rate: 0.0010
# Epoch 52/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 8.7838e-04 - val_loss: 0.0027 - learning_rate: 0.0010
# Epoch 53/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 8.7194e-04 - val_loss: 0.0025 - learning_rate: 0.0010
# Epoch 54/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 9.1156e-04 - val_loss: 0.0024 - learning_rate: 0.0010
# Epoch 55/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 8.1080e-04 - val_loss: 0.0024 - learning_rate: 0.0010
# Epoch 56/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 8.6843e-04 - val_loss: 0.0024 - learning_rate: 0.0010
# Epoch 57/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 8.1767e-04 - val_loss: 0.0024 - learning_rate: 0.0010
# Epoch 58/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 7.8562e-04 - val_loss: 0.0025 - learning_rate: 0.0010
# Epoch 59/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 7.9095e-04 - val_loss: 0.0024 - learning_rate: 0.0010
# Epoch 60/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 8.1058e-04 - val_loss: 0.0025 - learning_rate: 0.0010
# Epoch 61/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 7.4136e-04 - val_loss: 0.0023 - learning_rate: 0.0010
# Epoch 62/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 7.2361e-04 - val_loss: 0.0023 - learning_rate: 0.0010
# Epoch 63/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 6.9218e-04 - val_loss: 0.0023 - learning_rate: 0.0010
# Epoch 64/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 7.3395e-04 - val_loss: 0.0023 - learning_rate: 0.0010
# Epoch 65/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 7.2282e-04 - val_loss: 0.0024 - learning_rate: 0.0010
# Epoch 66/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 7.1549e-04 - val_loss: 0.0024 - learning_rate: 0.0010
# Epoch 67/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 6.3461e-04 - val_loss: 0.0023 - learning_rate: 0.0010
# Epoch 68/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 6.6224e-04 - val_loss: 0.0023 - learning_rate: 0.0010
# Epoch 69/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 6.6708e-04 - val_loss: 0.0022 - learning_rate: 0.0010
# Epoch 70/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 6.1024e-04 - val_loss: 0.0021 - learning_rate: 0.0010
# Epoch 71/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 6.1084e-04 - val_loss: 0.0022 - learning_rate: 0.0010
# Epoch 72/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 5.6661e-04 - val_loss: 0.0022 - learning_rate: 0.0010
# Epoch 73/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 5.6549e-04 - val_loss: 0.0021 - learning_rate: 0.0010
# Epoch 74/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 5.9230e-04 - val_loss: 0.0022 - learning_rate: 0.0010
# Epoch 75/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 6.3486e-04 - val_loss: 0.0022 - learning_rate: 0.0010
# Epoch 76/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 6.0914e-04 - val_loss: 0.0021 - learning_rate: 0.0010
# Epoch 77/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 5.5659e-04 - val_loss: 0.0020 - learning_rate: 0.0010
# Epoch 78/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 5.2313e-04 - val_loss: 0.0020 - learning_rate: 0.0010
# Epoch 79/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 6.5465e-04 - val_loss: 0.0021 - learning_rate: 0.0010
# Epoch 80/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 6.9357e-04 - val_loss: 0.0021 - learning_rate: 0.0010
# Epoch 81/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 5.4002e-04 - val_loss: 0.0020 - learning_rate: 0.0010
# Epoch 82/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 5.8279e-04 - val_loss: 0.0020 - learning_rate: 0.0010
# Epoch 83/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 5.4021e-04
# Epoch 83: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 5.3934e-04 - val_loss: 0.0021 - learning_rate: 0.0010
# Epoch 84/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 4.8868e-04 - val_loss: 0.0021 - learning_rate: 5.0000e-04
# Epoch 85/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 4.9624e-04 - val_loss: 0.0021 - learning_rate: 5.0000e-04
# Epoch 86/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 4.8125e-04 - val_loss: 0.0020 - learning_rate: 5.0000e-04
# Epoch 87/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 4.8036e-04 - val_loss: 0.0020 - learning_rate: 5.0000e-04
# Epoch 88/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 4.5395e-04 - val_loss: 0.0020 - learning_rate: 5.0000e-04
# Epoch 89/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 4.5368e-04 - val_loss: 0.0020 - learning_rate: 5.0000e-04
# Epoch 90/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 4.6466e-04 - val_loss: 0.0020 - learning_rate: 5.0000e-04
# Epoch 91/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 4.4785e-04 - val_loss: 0.0020 - learning_rate: 5.0000e-04
# Epoch 92/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 4.4232e-04 - val_loss: 0.0019 - learning_rate: 5.0000e-04
# Epoch 93/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 4.3402e-04 - val_loss: 0.0020 - learning_rate: 5.0000e-04
# Epoch 94/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 4.5009e-04 - val_loss: 0.0020 - learning_rate: 5.0000e-04
# Epoch 95/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 4.4028e-04 - val_loss: 0.0020 - learning_rate: 5.0000e-04
# Epoch 96/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 4.2932e-04 - val_loss: 0.0021 - learning_rate: 5.0000e-04
# Epoch 97/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 4.6587e-04 - val_loss: 0.0020 - learning_rate: 5.0000e-04
# Epoch 98/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 4.3540e-04 - val_loss: 0.0020 - learning_rate: 5.0000e-04
# Epoch 99/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 4.2901e-04 - val_loss: 0.0020 - learning_rate: 5.0000e-04
# Epoch 100/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 4.7227e-04 - val_loss: 0.0020 - learning_rate: 5.0000e-04
# Epoch 101/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 4.6156e-04 - val_loss: 0.0022 - learning_rate: 5.0000e-04
# Epoch 102/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 4.7174e-04
# Epoch 102: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 4.7063e-04 - val_loss: 0.0020 - learning_rate: 5.0000e-04
# Epoch 103/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 4.1565e-04 - val_loss: 0.0020 - learning_rate: 2.5000e-04
# Epoch 104/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 4.1665e-04 - val_loss: 0.0020 - learning_rate: 2.5000e-04
# Epoch 105/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 3.9856e-04 - val_loss: 0.0020 - learning_rate: 2.5000e-04
# Epoch 106/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 4.0440e-04 - val_loss: 0.0019 - learning_rate: 2.5000e-04
# Epoch 107/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 4.1633e-04 - val_loss: 0.0020 - learning_rate: 2.5000e-04
# Epoch 108/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 4.0214e-04 - val_loss: 0.0020 - learning_rate: 2.5000e-04
# Epoch 109/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 3.9817e-04 - val_loss: 0.0020 - learning_rate: 2.5000e-04
# Epoch 110/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 3.9872e-04 - val_loss: 0.0019 - learning_rate: 2.5000e-04
# Epoch 111/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 4.1061e-04 - val_loss: 0.0020 - learning_rate: 2.5000e-04
# Epoch 112/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 3.9857e-04
# Epoch 112: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 3.9756e-04 - val_loss: 0.0020 - learning_rate: 2.5000e-04
# Epoch 113/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 4.0094e-04 - val_loss: 0.0019 - learning_rate: 1.2500e-04
# Epoch 114/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 3.8607e-04 - val_loss: 0.0020 - learning_rate: 1.2500e-04
# Epoch 115/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 3.9988e-04 - val_loss: 0.0019 - learning_rate: 1.2500e-04
# Epoch 116/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 3.8422e-04 - val_loss: 0.0019 - learning_rate: 1.2500e-04
# Epoch 117/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 3.8560e-04 - val_loss: 0.0021 - learning_rate: 1.2500e-04
# Epoch 118/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 3.9882e-04 - val_loss: 0.0020 - learning_rate: 1.2500e-04
# Epoch 119/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 4.0065e-04 - val_loss: 0.0020 - learning_rate: 1.2500e-04
# Epoch 120/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 3.8486e-04 - val_loss: 0.0020 - learning_rate: 1.2500e-04
# Epoch 121/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 3.9037e-04 - val_loss: 0.0020 - learning_rate: 1.2500e-04
# Epoch 122/150
# 34/35 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 3.8684e-04
# Epoch 122: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 3.8454e-04 - val_loss: 0.0019 - learning_rate: 1.2500e-04
# Epoch 123/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 3.8084e-04 - val_loss: 0.0019 - learning_rate: 6.2500e-05
# Epoch 124/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 3.8627e-04 - val_loss: 0.0020 - learning_rate: 6.2500e-05
# Epoch 125/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 3.8518e-04 - val_loss: 0.0020 - learning_rate: 6.2500e-05
# Epoch 126/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 3.6914e-04 - val_loss: 0.0021 - learning_rate: 6.2500e-05
# Epoch 127/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 3.8604e-04 - val_loss: 0.0020 - learning_rate: 6.2500e-05
# Epoch 128/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 3.7375e-04 - val_loss: 0.0020 - learning_rate: 6.2500e-05
# Epoch 129/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 3.7937e-04 - val_loss: 0.0020 - learning_rate: 6.2500e-05
# Epoch 130/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 3.7507e-04 - val_loss: 0.0019 - learning_rate: 6.2500e-05
# Epoch 131/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 3.6212e-04 - val_loss: 0.0020 - learning_rate: 6.2500e-05
# Epoch 132/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 3.6981e-04
# Epoch 132: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 3.6900e-04 - val_loss: 0.0020 - learning_rate: 6.2500e-05
# Epoch 133/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 3.8017e-04 - val_loss: 0.0020 - learning_rate: 3.1250e-05
# Epoch 134/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 3.6922e-04 - val_loss: 0.0020 - learning_rate: 3.1250e-05
# Epoch 135/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 3.7729e-04 - val_loss: 0.0020 - learning_rate: 3.1250e-05
# Epoch 136/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 3.7031e-04 - val_loss: 0.0020 - learning_rate: 3.1250e-05
# Epoch 137/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 3.7942e-04 - val_loss: 0.0020 - learning_rate: 3.1250e-05
# Epoch 138/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 3.6787e-04 - val_loss: 0.0019 - learning_rate: 3.1250e-05
# Epoch 139/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 3.7365e-04 - val_loss: 0.0020 - learning_rate: 3.1250e-05
# Epoch 140/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 3.6638e-04 - val_loss: 0.0020 - learning_rate: 3.1250e-05
# Epoch 141/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 3.6653e-04 - val_loss: 0.0019 - learning_rate: 3.1250e-05
# Epoch 142/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 3.8167e-04
# Epoch 142: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 3.8054e-04 - val_loss: 0.0019 - learning_rate: 3.1250e-05
# Epoch 143/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 3.6784e-04 - val_loss: 0.0019 - learning_rate: 1.5625e-05
# Epoch 144/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 3.7244e-04 - val_loss: 0.0020 - learning_rate: 1.5625e-05
# Epoch 145/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 3.7284e-04 - val_loss: 0.0019 - learning_rate: 1.5625e-05
# Epoch 146/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 3.6973e-04 - val_loss: 0.0019 - learning_rate: 1.5625e-05
# Epoch 147/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 3.7695e-04 - val_loss: 0.0019 - learning_rate: 1.5625e-05
# Epoch 148/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 3.6880e-04 - val_loss: 0.0019 - learning_rate: 1.5625e-05
# Epoch 149/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 3.7847e-04 - val_loss: 0.0019 - learning_rate: 1.5625e-05
# Epoch 150/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 3.6820e-04 - val_loss: 0.0020 - learning_rate: 1.5625e-05
# BiGRU_2feat training completed.
# Performing rolling prediction with BiGRU_2feat...
# BiGRU_2feat rolling prediction completed.
# BiGRU_2feat R² falls below Utide at step: Never

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from keras.models import Model
from keras.layers import Dense, GRU, Dropout, Bidirectional, Input
from keras.regularizers import l2
from keras.optimizers import Adam
from keras.callbacks import ReduceLROnPlateau
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
import warnings
from sklearn.exceptions import UndefinedMetricWarning
import tensorflow as tf

np.random.seed(42)
tf.random.set_seed(42)
warnings.filterwarnings("ignore", category=UndefinedMetricWarning)

input_file = "dataProcessed/ABE5Y1_HA_processed.csv"
df = pd.read_csv(input_file, delimiter=',')
total_train_points = 10000
look_back_points = 100
total_test_points = 2000

total_required = total_train_points + look_back_points + total_test_points
if len(df) < total_required:
    raise ValueError(f"Dataset too small. Required: {total_required}, Current: {len(df)}")

max_start_index = len(df) - total_required
start_index = np.random.randint(0, max_start_index + 1)
print(f"Selected start index: {start_index}")

df_sampled = df.iloc[start_index:start_index + total_required].reset_index(drop=True)

anomaly = df_sampled['anomaly'].values.reshape(-1, 1)
utide = df_sampled['utide'].values.reshape(-1, 1)

utide_factor = 0.5
utide = utide * utide_factor

scaler_anomaly = MinMaxScaler(feature_range=(0, 1))
anomaly_scaled = scaler_anomaly.fit_transform(anomaly)

scaler_utide = MinMaxScaler(feature_range=(0, 1))
utide_scaled = scaler_utide.fit_transform(utide)

dataset_scaled_multi = np.hstack((anomaly_scaled, utide_scaled))
train_multi = dataset_scaled_multi[:total_train_points]
test_multi = dataset_scaled_multi[total_train_points : total_train_points + total_test_points + look_back_points]

def create_dataset_multi(dataset, look_back):
    dataX, dataY = [], []
    for i in range(len(dataset)-look_back):
        a = dataset[i:(i+look_back), :]
        dataX.append(a)
        dataY.append(dataset[i+look_back, 0])
    return np.array(dataX), np.array(dataY)

trainX_multi, trainY_multi = create_dataset_multi(train_multi, look_back_points)
testX_multi, testY_multi = create_dataset_multi(test_multi, look_back_points)

print("Multi-feature TrainX:", trainX_multi.shape, "TrainY:", trainY_multi.shape)
print("Multi-feature TestX:", testX_multi.shape, "TestY:", testY_multi.shape)

num_features_multi = 2

# bigru
def build_bigru_multi(input_shape):
    input_layer = Input(shape=input_shape)
    x = Bidirectional(GRU(700, return_sequences=True, kernel_regularizer=l2(0.0001)))(input_layer)
    x = Dropout(0.3)(x)
    x = Bidirectional(GRU(500, kernel_regularizer=l2(0.0001)))(x)
    x = Dropout(0.3)(x)
    output_layer = Dense(1)(x)
    model = Model(inputs=input_layer, outputs=output_layer)
    model.compile(loss='mse', optimizer=Adam(learning_rate=0.001))
    return model

model = build_bigru_multi((look_back_points, num_features_multi))

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, verbose=1, min_lr=1e-6)

epochs = 150
batch_size = 256

print("Training BiGRU_2feat...")
history = model.fit(trainX_multi, trainY_multi,
                    validation_split=0.1,
                    epochs=epochs,
                    batch_size=batch_size,
                    verbose=1,
                    callbacks=[reduce_lr])
print("BiGRU_2feat training completed.\n")

plt.figure(figsize=(12,8))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('BiGRU_2feat Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

#rolling
def rolling_prediction_multi(model, test, scaler_anomaly, scaler_utide, look_back):
    total_tp = len(test) - look_back
    current_input = test[:look_back].copy()
    rolling_predictions = []
    actual_values = []
    utide_values = []
    r2_scores = []
    utide_r2_scores = []

    for i in range(total_tp):
        input_sequence = current_input.reshape(1, look_back, 2)
        prediction = model.predict(input_sequence, verbose=0)
        predicted_anomaly_scaled = prediction[0, 0]

        actual_anomaly_scaled = test[look_back + i, 0]
        actual_anomaly = scaler_anomaly.inverse_transform([[actual_anomaly_scaled]])[0, 0]
        actual_values.append(actual_anomaly)

        utide_scaled_val = test[look_back + i, 1]
        utide_val = scaler_utide.inverse_transform([[utide_scaled_val]])[0, 0]
        utide_values.append(utide_val)

        predicted_anomaly = scaler_anomaly.inverse_transform([[predicted_anomaly_scaled]])[0,0]
        rolling_predictions.append(predicted_anomaly)

        current_input = np.roll(current_input, -1, axis=0)
        if i < total_tp - 1:
            next_utide_scaled = test[look_back + i + 1, 1]
        else:
            next_utide_scaled = test[look_back + i, 1]

        current_input[-1, 0] = predicted_anomaly_scaled
        current_input[-1, 1] = next_utide_scaled

        if i >= 20:
            r2_scores.append(r2_score(actual_values, rolling_predictions))
            utide_r2_scores.append(r2_score(actual_values, utide_values))
        else:
            r2_scores.append(np.nan)
            utide_r2_scores.append(np.nan)

    return {
        'actual_values': np.array(actual_values),
        'predicted_values': np.array(rolling_predictions),
        'utide_values': np.array(utide_values),
        'r2_scores': np.array(r2_scores),
        'utide_r2_scores': np.array(utide_r2_scores)
    }

print("Performing rolling prediction with BiGRU_2feat...")
results = rolling_prediction_multi(model, test_multi, scaler_anomaly, scaler_utide, look_back_points)
print("BiGRU_2feat rolling prediction completed.\n")

actual_values_full = scaler_anomaly.inverse_transform(
    test_multi[look_back_points:look_back_points + total_test_points, 0].reshape(-1,1)).flatten()
utide_values_full = scaler_utide.inverse_transform(
    test_multi[look_back_points:look_back_points + total_test_points, 1].reshape(-1,1)).flatten()

#r2、MSE、MAE

r2 = r2_score(actual_values_full, results['predicted_values'])
mse_300 = mean_squared_error(actual_values_full[:300], results['predicted_values'][:300])
mae_300 = mean_absolute_error(actual_values_full[:300], results['predicted_values'][:300])

print(f"R²: {r2:.4f}, MSE (First 300 Steps): {mse_300:.4f}, MAE (First 300 Steps): {mae_300:.4f}")

# 绘制预测对比图
plt.figure(figsize=(20,10))
plt.plot(actual_values_full[:100], label='Actual', color='black')
plt.plot(utide_values_full[:100], label='Utide', color='green', linestyle='--')
plt.plot(results['predicted_values'][:100], label='BiGRU_2feat Prediction', color='red')
plt.xlabel('Time Step')
plt.ylabel('Anomaly')
plt.title('Predictions vs Actual (First 100 Steps)')
plt.legend()
plt.show()
# Out:
# Selected start index: 121958
# Multi-feature TrainX: (9900, 100, 2) TrainY: (9900,)
# Multi-feature TestX: (2000, 100, 2) TestY: (2000,)
# Training BiGRU_2feat...
# Epoch 1/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 8s 82ms/step - loss: 0.4164 - val_loss: 0.1180 - learning_rate: 0.0010
# Epoch 2/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 0.1035 - val_loss: 0.0858 - learning_rate: 0.0010
# Epoch 3/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 0.0815 - val_loss: 0.0745 - learning_rate: 0.0010
# Epoch 4/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 0.0709 - val_loss: 0.0653 - learning_rate: 0.0010
# Epoch 5/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 0.0620 - val_loss: 0.0575 - learning_rate: 0.0010
# Epoch 6/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 0.0545 - val_loss: 0.0507 - learning_rate: 0.0010
# Epoch 7/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 0.0480 - val_loss: 0.0448 - learning_rate: 0.0010
# Epoch 8/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 0.0423 - val_loss: 0.0398 - learning_rate: 0.0010
# Epoch 9/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 0.0374 - val_loss: 0.0354 - learning_rate: 0.0010
# Epoch 10/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 0.0332 - val_loss: 0.0315 - learning_rate: 0.0010
# Epoch 11/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 0.0295 - val_loss: 0.0282 - learning_rate: 0.0010
# Epoch 12/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 0.0262 - val_loss: 0.0252 - learning_rate: 0.0010
# Epoch 13/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 0.0234 - val_loss: 0.0226 - learning_rate: 0.0010
# Epoch 14/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 0.0208 - val_loss: 0.0204 - learning_rate: 0.0010
# Epoch 15/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 0.0186 - val_loss: 0.0184 - learning_rate: 0.0010
# Epoch 16/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 0.0167 - val_loss: 0.0167 - learning_rate: 0.0010
# Epoch 17/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 0.0149 - val_loss: 0.0151 - learning_rate: 0.0010
# Epoch 18/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 0.0134 - val_loss: 0.0138 - learning_rate: 0.0010
# Epoch 19/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 0.0121 - val_loss: 0.0128 - learning_rate: 0.0010
# Epoch 20/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 0.0109 - val_loss: 0.0118 - learning_rate: 0.0010
# Epoch 21/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 0.0098 - val_loss: 0.0107 - learning_rate: 0.0010
# Epoch 22/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 0.0089 - val_loss: 0.0098 - learning_rate: 0.0010
# Epoch 23/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 0.0080 - val_loss: 0.0088 - learning_rate: 0.0010
# Epoch 24/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 0.0072 - val_loss: 0.0083 - learning_rate: 0.0010
# Epoch 25/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 0.0066 - val_loss: 0.0076 - learning_rate: 0.0010
# Epoch 26/150
# 24/35 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0060
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-4-316e23e5244c>", line 94, in <cell line: 94>
#     history = model.fit(trainX_multi, trainY_multi,
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 117, in error_handler
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/backend/tensorflow/trainer.py", line 320, in fit
#     logs = self.train_function(iterator)
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py", line 150, in error_handler
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py", line 833, in __call__
#     result = self._call(*args, **kwds)
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py", line 878, in _call
#     results = tracing_compilation.call_function(
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py", line 139, in call_function
#     return function._call_flat(  # pylint: disable=protected-access
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py", line 1322, in _call_flat
#     return self._inference_function.call_preflattened(args)
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py", line 216, in call_preflattened
#     flat_outputs = self.call_flat(*args)
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py", line 251, in call_flat
#     outputs = self._bound_context.call_function(
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/context.py", line 1552, in call_function
#     outputs = execute.execute(
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/execute.py", line 53, in quick_execute
#     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1624, in getframeinfo
#     lines, lnum = findsource(frame)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 182, in findsource
#     lines = linecache.getlines(file, globals_dict)
#   File "/usr/lib/python3.10/linecache.py", line 46, in getlines
#     return updatecache(filename, module_globals)
#   File "/usr/lib/python3.10/linecache.py", line 137, in updatecache
#     lines = fp.readlines()
#   File "/usr/lib/python3.10/codecs.py", line 319, in decode
#     def decode(self, input, final=False):
# KeyboardInterrupt
# KeyboardInterrupt

# %% [markdown]
# # 10 times of rolling forcasting with different weight of utide (0.6 0.7)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from keras.models import Model
from keras.layers import Dense, GRU, Dropout, Bidirectional, Input
from keras.regularizers import l2
from keras.optimizers import Adam
from keras.callbacks import ReduceLROnPlateau
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
import warnings
from sklearn.exceptions import UndefinedMetricWarning
import tensorflow as tf

# np.random.seed(42)
# tf.random.set_seed(42)
warnings.filterwarnings("ignore", category=UndefinedMetricWarning)


input_file = "dataProcessed/ABE5Y1_HA_processed.csv"
df = pd.read_csv(input_file, delimiter=',')
total_train_points = 10000
look_back_points = 100
total_test_points = 2000

total_required = total_train_points + look_back_points + total_test_points
if len(df) < total_required:
    raise ValueError(f"Dataset too small.")

max_start_index = len(df) - total_required
start_index = np.random.randint(0, max_start_index + 1)
print(f"Selected start index: {start_index}")

df_sampled = df.iloc[start_index:start_index + total_required].reset_index(drop=True)

anomaly = df_sampled['anomaly'].values.reshape(-1, 1)
utide_original = df_sampled['utide'].values.reshape(-1, 1)

scaler_anomaly = MinMaxScaler(feature_range=(0, 1))
anomaly_scaled = scaler_anomaly.fit_transform(anomaly)

scaler_utide = MinMaxScaler(feature_range=(0, 1))

def create_dataset_multi(dataset, look_back):
    dataX, dataY = [], []
    for i in range(len(dataset)-look_back):
        a = dataset[i:(i+look_back), :]
        dataX.append(a)
        dataY.append(dataset[i+look_back, 0])
    return np.array(dataX), np.array(dataY)

def build_bigru_multi(input_shape):
    input_layer = Input(shape=input_shape)
    x = Bidirectional(GRU(500, return_sequences=True, kernel_regularizer=l2(0.0001)))(input_layer)
    x = Dropout(0.3)(x)
    x = Bidirectional(GRU(500, kernel_regularizer=l2(0.0001)))(x)
    x = Dropout(0.3)(x)
    output_layer = Dense(1)(x)
    model = Model(inputs=input_layer, outputs=output_layer)
    model.compile(loss='mse', optimizer=Adam(learning_rate=0.001))
    return model

def rolling_prediction_multi(model, test, scaler_anomaly, scaler_utide, look_back):
    total_tp = len(test) - look_back
    current_input = test[:look_back].copy()
    rolling_predictions = []
    actual_values = []
    utide_values = []
    for i in range(total_tp):
        input_sequence = current_input.reshape(1, look_back, 2)
        prediction = model.predict(input_sequence, verbose=0)
        predicted_anomaly_scaled = prediction[0, 0]

        actual_anomaly_scaled = test[look_back + i, 0]
        actual_anomaly = scaler_anomaly.inverse_transform([[actual_anomaly_scaled]])[0, 0]
        actual_values.append(actual_anomaly)

        utide_scaled_val = test[look_back + i, 1]
        utide_val = scaler_utide.inverse_transform([[utide_scaled_val]])[0, 0]
        utide_values.append(utide_val)

        predicted_anomaly = scaler_anomaly.inverse_transform([[predicted_anomaly_scaled]])[0,0]
        rolling_predictions.append(predicted_anomaly)

        current_input = np.roll(current_input, -1, axis=0)
        if i < total_tp - 1:
            next_utide_scaled = test[look_back + i + 1, 1]
        else:
            next_utide_scaled = test[look_back + i, 1]
        current_input[-1, 0] = predicted_anomaly_scaled
        current_input[-1, 1] = next_utide_scaled

    return np.array(actual_values), np.array(rolling_predictions), np.array(utide_values)

utide_factors = np.linspace(1.0, 0.0, 11)

all_predictions = []
all_mse = []
all_mae = []
all_r2 = []

actual_values_full = None
utide_values_full = None

for factor in utide_factors:
    print(f"Training with utide_factor={factor:.1f}")
    utide = utide_original * factor
    utide_scaled = scaler_utide.fit_transform(utide)
    dataset_scaled_multi = np.hstack((anomaly_scaled, utide_scaled))
    train_multi = dataset_scaled_multi[:total_train_points]
    test_multi = dataset_scaled_multi[total_train_points : total_train_points + total_test_points + look_back_points]

    trainX_multi, trainY_multi = create_dataset_multi(train_multi, look_back_points)
    testX_multi, testY_multi = create_dataset_multi(test_multi, look_back_points)

    model = build_bigru_multi((look_back_points, 2))

    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, verbose=1, min_lr=1e-6)

    epochs = 50
    batch_size = 256

    model.fit(trainX_multi, trainY_multi,
              validation_split=0.1,
              epochs=epochs,
              batch_size=batch_size,
              verbose=1,
              callbacks=[reduce_lr])

    actual_values, predictions, utide_values = rolling_prediction_multi(model, test_multi, scaler_anomaly, scaler_utide, look_back_points)
    if actual_values_full is None:
        actual_values_full = actual_values
        utide_values_full = utide_values

    mse_val = mean_squared_error(actual_values, predictions)
    mae_val = mean_absolute_error(actual_values, predictions)
    r2_val = r2_score(actual_values, predictions)

    all_predictions.append(predictions)
    all_mse.append(mse_val)
    all_mae.append(mae_val)
    all_r2.append(r2_val)

steps_to_plot = 100
plt.figure(figsize=(20,10))
plt.plot(actual_values_full[:steps_to_plot], label='Actual', color='black', linewidth=2)
plt.plot(utide_values_full[:steps_to_plot], label='Utide', color='green', linestyle='--', linewidth=2)

colors = plt.cm.viridis(np.linspace(0,1,len(utide_factors)))
for i, factor in enumerate(utide_factors):
    plt.plot(all_predictions[i][:steps_to_plot], label=f'Factor={factor:.1f}', color=colors[i])

plt.xlabel('Time Step')
plt.ylabel('Anomaly')
plt.title('BiGRU Predictions vs Actual for different Utide factors')
plt.legend()
plt.show()

x = np.arange(len(utide_factors))
width = 0.3

fig, axes = plt.subplots(1,3, figsize=(20,8))

# MSE
axes[0].bar(x, all_mse, width, color='blue')
axes[0].set_title('MSE')
axes[0].set_xlabel('Utide Factor')
axes[0].set_ylabel('MSE')
axes[0].set_xticks(x)
axes[0].set_xticklabels([f"{f:.1f}" for f in utide_factors])

# MAE
axes[1].bar(x, all_mae, width, color='orange')
axes[1].set_title('MAE')
axes[1].set_xlabel('Utide Factor')
axes[1].set_ylabel('MAE')
axes[1].set_xticks(x)
axes[1].set_xticklabels([f"{f:.1f}" for f in utide_factors])

# R²
axes[2].bar(x, all_r2, width, color='red')
axes[2].set_title('R²')
axes[2].set_xlabel('Utide Factor')
axes[2].set_ylabel('R²')
axes[2].set_xticks(x)
axes[2].set_xticklabels([f"{f:.1f}" for f in utide_factors])

plt.tight_layout()
plt.show()
# Out:
# Selected start index: 146867
# Training with utide_factor=1.0
# Epoch 1/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 65ms/step - loss: 0.3050 - val_loss: 0.0944 - learning_rate: 0.0010
# Epoch 2/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0846 - val_loss: 0.0658 - learning_rate: 0.0010
# Epoch 3/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0641 - val_loss: 0.0558 - learning_rate: 0.0010
# Epoch 4/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0546 - val_loss: 0.0478 - learning_rate: 0.0010
# Epoch 5/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0469 - val_loss: 0.0411 - learning_rate: 0.0010
# Epoch 6/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0404 - val_loss: 0.0354 - learning_rate: 0.0010
# Epoch 7/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0349 - val_loss: 0.0307 - learning_rate: 0.0010
# Epoch 8/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0303 - val_loss: 0.0266 - learning_rate: 0.0010
# Epoch 9/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0263 - val_loss: 0.0232 - learning_rate: 0.0010
# Epoch 10/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0229 - val_loss: 0.0203 - learning_rate: 0.0010
# Epoch 11/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0200 - val_loss: 0.0177 - learning_rate: 0.0010
# Epoch 12/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0176 - val_loss: 0.0155 - learning_rate: 0.0010
# Epoch 13/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0155 - val_loss: 0.0137 - learning_rate: 0.0010
# Epoch 14/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 0.0137 - val_loss: 0.0120 - learning_rate: 0.0010
# Epoch 15/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0121 - val_loss: 0.0106 - learning_rate: 0.0010
# Epoch 16/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0107 - val_loss: 0.0096 - learning_rate: 0.0010
# Epoch 17/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0096 - val_loss: 0.0083 - learning_rate: 0.0010
# Epoch 18/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0085 - val_loss: 0.0074 - learning_rate: 0.0010
# Epoch 19/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 0.0075 - val_loss: 0.0067 - learning_rate: 0.0010
# Epoch 20/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 0.0068 - val_loss: 0.0058 - learning_rate: 0.0010
# Epoch 21/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0060 - val_loss: 0.0052 - learning_rate: 0.0010
# Epoch 22/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0054 - val_loss: 0.0046 - learning_rate: 0.0010
# Epoch 23/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0048 - val_loss: 0.0042 - learning_rate: 0.0010
# Epoch 24/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0044 - val_loss: 0.0038 - learning_rate: 0.0010
# Epoch 25/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0039 - val_loss: 0.0033 - learning_rate: 0.0010
# Epoch 26/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0036 - val_loss: 0.0033 - learning_rate: 0.0010
# Epoch 27/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0034 - val_loss: 0.0027 - learning_rate: 0.0010
# Epoch 28/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0030 - val_loss: 0.0024 - learning_rate: 0.0010
# Epoch 29/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0027 - val_loss: 0.0022 - learning_rate: 0.0010
# Epoch 30/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0025 - val_loss: 0.0021 - learning_rate: 0.0010
# Epoch 31/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0023 - val_loss: 0.0019 - learning_rate: 0.0010
# Epoch 32/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0021 - val_loss: 0.0017 - learning_rate: 0.0010
# Epoch 33/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0019 - val_loss: 0.0015 - learning_rate: 0.0010
# Epoch 34/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0017 - val_loss: 0.0013 - learning_rate: 0.0010
# Epoch 35/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0016 - val_loss: 0.0012 - learning_rate: 0.0010
# Epoch 36/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0016 - val_loss: 0.0011 - learning_rate: 0.0010
# Epoch 37/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0014 - val_loss: 0.0010 - learning_rate: 0.0010
# Epoch 38/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0013 - val_loss: 9.5046e-04 - learning_rate: 0.0010
# Epoch 39/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0012 - val_loss: 8.9595e-04 - learning_rate: 0.0010
# Epoch 40/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0011 - val_loss: 7.8669e-04 - learning_rate: 0.0010
# Epoch 41/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0011 - val_loss: 7.2330e-04 - learning_rate: 0.0010
# Epoch 42/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0010 - val_loss: 0.0011 - learning_rate: 0.0010
# Epoch 43/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0010 - val_loss: 6.4619e-04 - learning_rate: 0.0010
# Epoch 44/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 9.2513e-04 - val_loss: 6.5943e-04 - learning_rate: 0.0010
# Epoch 45/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 9.1830e-04 - val_loss: 5.4830e-04 - learning_rate: 0.0010
# Epoch 46/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 8.3378e-04 - val_loss: 5.3990e-04 - learning_rate: 0.0010
# Epoch 47/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 8.2006e-04 - val_loss: 5.0359e-04 - learning_rate: 0.0010
# Epoch 48/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 7.4800e-04 - val_loss: 5.0036e-04 - learning_rate: 0.0010
# Epoch 49/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 7.1890e-04 - val_loss: 4.5167e-04 - learning_rate: 0.0010
# Epoch 50/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 7.3318e-04 - val_loss: 4.9078e-04 - learning_rate: 0.0010
# Training with utide_factor=0.9
# Epoch 1/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 65ms/step - loss: 0.3193 - val_loss: 0.0964 - learning_rate: 0.0010
# Epoch 2/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0867 - val_loss: 0.0678 - learning_rate: 0.0010
# Epoch 3/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0664 - val_loss: 0.0582 - learning_rate: 0.0010
# Epoch 4/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0572 - val_loss: 0.0506 - learning_rate: 0.0010
# Epoch 5/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 0.0498 - val_loss: 0.0441 - learning_rate: 0.0010
# Epoch 6/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 0.0434 - val_loss: 0.0385 - learning_rate: 0.0010
# Epoch 7/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0380 - val_loss: 0.0337 - learning_rate: 0.0010
# Epoch 8/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0333 - val_loss: 0.0296 - learning_rate: 0.0010
# Epoch 9/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0293 - val_loss: 0.0261 - learning_rate: 0.0010
# Epoch 10/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0258 - val_loss: 0.0230 - learning_rate: 0.0010
# Epoch 11/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0227 - val_loss: 0.0203 - learning_rate: 0.0010
# Epoch 12/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0201 - val_loss: 0.0180 - learning_rate: 0.0010
# Epoch 13/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0179 - val_loss: 0.0159 - learning_rate: 0.0010
# Epoch 14/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0159 - val_loss: 0.0142 - learning_rate: 0.0010
# Epoch 15/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0141 - val_loss: 0.0126 - learning_rate: 0.0010
# Epoch 16/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0126 - val_loss: 0.0113 - learning_rate: 0.0010
# Epoch 17/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0112 - val_loss: 0.0100 - learning_rate: 0.0010
# Epoch 18/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.
-04 - learning_rate: 0.0010
# Epoch 44/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 8.8384e-04 - val_loss: 8.1266e-04 - learning_rate: 0.0010
# Epoch 45/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 8.9462e-04 - val_loss: 6.3048e-04 - learning_rate: 0.0010
# Epoch 46/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 9.1209e-04 - val_loss: 5.1683e-04 - learning_rate: 0.0010
# Epoch 47/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 7.7970e-04 - val_loss: 5.4024e-04 - learning_rate: 0.0010
# Epoch 48/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 7.5418e-04 - val_loss: 5.0773e-04 - learning_rate: 0.0010
# Epoch 49/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 7.3264e-04 - val_loss: 4.1739e-04 - learning_rate: 0.0010
# Epoch 50/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 6.7373e-04 - val_loss: 4.0733e-04 - learning_rate: 0.0010
# Training with utide_factor=0.0
# Epoch 1/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - loss: 0.2500 - val_loss: 0.0858 - learning_rate: 0.0010
# Epoch 2/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0765 - val_loss: 0.0577 - learning_rate: 0.0010
# Epoch 3/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0555 - val_loss: 0.0460 - learning_rate: 0.0010
# Epoch 4/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0445 - val_loss: 0.0370 - learning_rate: 0.0010
# Epoch 5/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0358 - val_loss: 0.0298 - learning_rate: 0.0010
# Epoch 6/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0289 - val_loss: 0.0242 - learning_rate: 0.0010
# Epoch 7/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0235 - val_loss: 0.0197 - learning_rate: 0.0010
# Epoch 8/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0191 - val_loss: 0.0161 - learning_rate: 0.0010
# Epoch 9/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0157 - val_loss: 0.0131 - learning_rate: 0.0010
# Epoch 10/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0129 - val_loss: 0.0108 - learning_rate: 0.0010
# Epoch 11/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0107 - val_loss: 0.0090 - learning_rate: 0.0010
# Epoch 12/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0089 - val_loss: 0.0075 - learning_rate: 0.0010
# Epoch 13/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0074 - val_loss: 0.0061 - learning_rate: 0.0010
# Epoch 14/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0062 - val_loss: 0.0051 - learning_rate: 0.0010
# Epoch 15/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0052 - val_loss: 0.0042 - learning_rate: 0.0010
# Epoch 16/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0044 - val_loss: 0.0036 - learning_rate: 0.0010
# Epoch 17/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0037 - val_loss: 0.0029 - learning_rate: 0.0010
# Epoch 18/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0031 - val_loss: 0.0024 - learning_rate: 0.0010
# Epoch 19/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0026 - val_loss: 0.0022 - learning_rate: 0.0010
# Epoch 20/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0023 - val_loss: 0.0019 - learning_rate: 0.0010
# Epoch 21/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0020 - val_loss: 0.0015 - learning_rate: 0.0010
# Epoch 22/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0017 - val_loss: 0.0012 - learning_rate: 0.0010
# Epoch 23/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0015 - val_loss: 0.0015 - learning_rate: 0.0010
# Epoch 24/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0016 - val_loss: 9.2986e-04 - learning_rate: 0.0010
# Epoch 25/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0012 - val_loss: 8.3985e-04 - learning_rate: 0.0010
# Epoch 26/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0011 - val_loss: 7.3635e-04 - learning_rate: 0.0010
# Epoch 27/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 9.6578e-04 - val_loss: 7.6088e-04 - learning_rate: 0.0010
# Epoch 28/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 8.7619e-04 - val_loss: 5.7282e-04 - learning_rate: 0.0010
# Epoch 29/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 8.9116e-04 - val_loss: 4.8966e-04 - learning_rate: 0.0010
# Epoch 30/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 7.8831e-04 - val_loss: 4.6176e-04 - learning_rate: 0.0010
# Epoch 31/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 7.3168e-04 - val_loss: 4.0847e-04 - learning_rate: 0.0010
# Epoch 32/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 6.6779e-04 - val_loss: 4.7935e-04 - learning_rate: 0.0010
# Epoch 33/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 6.7625e-04 - val_loss: 7.7450e-04 - learning_rate: 0.0010
# Epoch 34/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 7.6409e-04 - val_loss: 3.8363e-04 - learning_rate: 0.0010
# Epoch 35/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 5.9123e-04 - val_loss: 3.1709e-04 - learning_rate: 0.0010
# Epoch 36/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 5.5601e-04 - val_loss: 3.2360e-04 - learning_rate: 0.0010
# Epoch 37/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 5.9035e-04 - val_loss: 3.1661e-04 - learning_rate: 0.0010
# Epoch 38/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 5.5044e-04 - val_loss: 4.2599e-04 - learning_rate: 0.0010
# Epoch 39/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 6.0000e-04 - val_loss: 2.6381e-04 - learning_rate: 0.0010
# Epoch 40/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 6.6855e-04 - val_loss: 3.9713e-04 - learning_rate: 0.0010
# Epoch 41/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 5.3632e-04 - val_loss: 2.4454e-04 - learning_rate: 0.0010
# Epoch 42/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 4.8348e-04 - val_loss: 2.2995e-04 - learning_rate: 0.0010
# Epoch 43/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 4.9492e-04 - val_loss: 2.5119e-04 - learning_rate: 0.0010
# Epoch 44/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 5.2136e-04 - val_loss: 2.6538e-04 - learning_rate: 0.0010
# Epoch 45/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 5.0269e-04
# Epoch 45: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 5.0237e-04 - val_loss: 3.4142e-04 - learning_rate: 0.0010
# Epoch 46/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 4.7590e-04 - val_loss: 2.5208e-04 - learning_rate: 5.0000e-04
# Epoch 47/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 4.5201e-04 - val_loss: 2.3494e-04 - learning_rate: 5.0000e-04
# Epoch 48/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 4.5527e-04 - val_loss: 2.0388e-04 - learning_rate: 5.0000e-04
# Epoch 49/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 4.4247e-04 - val_loss: 2.0141e-04 - learning_rate: 5.0000e-04
# Epoch 50/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 4.2921e-04 - val_loss: 1.9246e-04 - learning_rate: 5.0000e-04
