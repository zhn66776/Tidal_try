# %%
# !git clone https://github.com/zhn66776/Tidal_try.git
# Out:
# Cloning into 'Tidal_try'...
# remote: Enumerating objects: 523, done.
# remote: Counting objects: 100% (168/168), done.
# remote: Compressing objects: 100% (168/168), done.
# remote: Total 523 (delta 90), reused 0 (delta 0), pack-reused 355 (from 1)
# Receiving objects: 100% (523/523), 59.48 MiB | 9.14 MiB/s, done.
# Resolving deltas: 100% (221/221), done.

# %%
cd Tidal_try
# Out:
# /content/Tidal_try

# %%
import torch
from torch.utils.data import DataLoader
from config import Config

from utils.datatool_autoreg import mydataReader, custom_dataset
from utils.model_autoreg import CNNBiLSTM
from utils.trainer_autoreg import CNNBiLstm_evaluate, CNNBiLstmtrain

if __name__ == '__main__':
    config = Config()

    print("Data loading...")

    dataset = mydataReader("./dataProcessed/can1998HA.csv")

    (train_X, train_Y), (val_X, val_Y), (test_X, test_Y) = dataset.split(lookback=config.lookback, trainSet_ratio=0.8, valSet_ratio=0.175)

    trainSet = custom_dataset(train_X, train_Y)
    valSet = custom_dataset(val_X, val_Y)


    train_loader = DataLoader(trainSet, batch_size=config.batch_size,
                              shuffle=False, pin_memory=True, num_workers=4, drop_last=True)
    val_loader = DataLoader(valSet, batch_size=config.batch_size,
                            shuffle=False, pin_memory=True, num_workers=4, drop_last=False)


    print("Model loading...")
    model = CNNBiLSTM(hidden_size=48, num_layers=4).to(config.device)
    criterion = torch.nn.MSELoss()
    optimizer = torch.optim.AdamW(model.parameters(),
                                  lr=config.learning_rate, weight_decay=config.weight_decay)
    print(f"Configuration Parameters:")
    print(f" - Batch size: {config.batch_size}")
    print(f" - Lookback: {config.lookback}")
    print(f" - Epochs: {config.epoch_size}")
    print(f" - Learning rate: {config.learning_rate}")
    print(f" - Weight decay: {config.weight_decay}")

    print("Training...")
    model = CNNBiLstmtrain(model,
                           trainloader=train_loader,
                           valloader=val_loader,
                           criterion=criterion,
                           optimizer=optimizer,
                           config=config)

    print("Testing...")

    initial_sequence = test_X[0]

    y_pred, y_true = CNNBiLstm_evaluate(model, initial_sequence, test_Y, config)
# Out:
# Data loading...
# 100%|██████████| 8730/8730 [00:00<00:00, 162822.22it/s]
# 测试集大小为219
# Model loading...
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:617: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# Configuration Parameters:
#  - Batch size: 128
#  - Lookback: 30
#  - Epochs: 30
#  - Learning rate: 0.0008
#  - Weight decay: 1e-05
# Training...
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:617: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# Epoch: 0 batch: 0 | loss: 0.3071058392524719
# Epoch: 0 batch: 10 | loss: 0.13299186527729034
# Epoch: 0 batch: 20 | loss: 0.04023182392120361
# Epoch: 0 batch: 30 | loss: 0.043812744319438934
# Epoch: 0 batch: 40 | loss: 0.058563124388456345
# Epoch: 0 batch: 50 | loss: 0.015846112743020058
# Epoch: 0 | Train Loss: 0.07821885860283617 | Val Loss: 0.039385101804556046
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:617: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# Epoch: 1 batch: 0 | loss: 0.021223342046141624
# Epoch: 1 batch: 10 | loss: 0.07758165150880814
# Epoch: 1 batch: 20 | loss: 0.03806409239768982
# Epoch: 1 batch: 30 | loss: 0.036814890801906586
# Epoch: 1 batch: 40 | loss: 0.056936923414468765
# Epoch: 1 batch: 50 | loss: 0.016313185915350914
# Epoch: 1 | Train Loss: 0.0400539460522985 | Val Loss: 0.03948042922507798
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:617: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# Epoch: